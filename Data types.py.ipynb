# %%
#list in python
#List is an ordered and changeable collection that can store multiples values
marks = [80 , 90 , 75 , 85]

print(marks)
# Out:
# [80, 90, 75, 85]

# %%
#accessing element in a list
marks = [80, 90, 75, 85 ]

print(marks[0])
print(marks[1])
print(marks[2])
# Out:
# 80
# 90
# 75

# %%
#accessing elements in the list
marks = [29, 64, 36, 91, 44, 79]

print(marks[0])
print(marks[1])
print(marks[2])
# Out:
# 29
# 64
# 36

# %%
#change element in a  list
marks = [80, 90, 75]

marks[1] = 95

print(marks)
# Out:
# [80, 95, 75]

# %%
#change element in list
marks = [79, 64, 92, 74, 96, 77, 94] 

marks[1] = 65
marks[3] = 87
marks[5] = 30

print (marks)
# Out:
# [79, 65, 92, 87, 96, 30, 94]

# %%
#add element in a list
marks = [80, 90, 75]

marks.append(85)

print(marks)
# Out:
# [80, 90, 75, 85]

# %%
#add element in a list
marks = [56, 46, 23]

marks.append(35)

print(marks)
# Out:
# [56, 46, 23, 35]

# %%
#add the elements
marks = [12, 13, 14]

marks.append(43)

print(marks)
# Out:
# [12, 13, 14, 43]

# %%
#remove elements from a list
marks = [80, 90, 75]  

marks.remove(90)

print(marks)
# Out:
# [80, 75]

# %%
#list of number
numbers = [10, 20, 30]

numbers.insert(1, 15)

print(numbers)
# Out:
# [10, 15, 20, 30]

# %%
numbers = [10, 20, 30]

numbers.insert(1, 15)

print(numbers)
# Out:
# [10, 15, 20, 30]

# %%
#insert numbers

numbers = [32, 14, 16]

numbers.insert(3, 15)

print(numbers)
# Out:
# [32, 14, 16, 15]

# %%
a = [1, 2, 3]
b = [4, 5, 6]

a . extend(b)

print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
#clear method
numbers = [10, 20, 30]

numbers.clear()

print(numbers)
# Out:
# []

# %%
#index method
numbers =[10, 20, 30, 40]

print(numbers.index(30))
# Out:
# 2

# %%
#count method
numbers = [10, 20, 20, 30, 20 ]

print(numbers.count(20))
# Out:
# 3

# %%
#sort method

numbers = [40, 10, 30, 20]

numbers.sort()

print(numbers)

numbers.sort(reverse=True)

print (numbers)
# Out:
# [10, 20, 30, 40]
# [40, 30, 20, 10]

# %%
#sort reverse method
numbers = [80, 90, 50, 70, 60]

numbers.sort(reverse=True)

print(numbers)
# Out:
# [90, 80, 70, 60, 50]

# %%
#revrse method

numbers = [10, 20, 30, 40]

numbers.reverse()

print (numbers)
# Out:
# [40, 30, 20, 10]

# %%
#copy method
a = [1, 2, 3]

b = a.copy()

print(b)
# Out:
# [1, 2, 3]

# %%
#colon method

numbers = [10, 20, 30, 40, 50]

print(numbers[1:4])
print(numbers[:3])
print(numbers[2:])
print(numbers[::-1])
print(numbers[-2::])
print(numbers[::-2])
print(numbers[::-5])
print(numbers[-1::])
# Out:
# [20, 30, 40]
# [10, 20, 30]
# [30, 40, 50]
# [50, 40, 30, 20, 10]
# [40, 50]
# [50, 30, 10]
# [50]
# [50]
